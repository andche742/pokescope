# %% [markdown]
# # Exploration

# %%
import sys
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

from scrape import cpm_scraper, stats_scraper
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## CPM

# %%
cpm = cpm_scraper.parse_cpm_table(cpm_scraper.fetch_html())
cpm.head()
# Out:
#    level     value
# 0    1.0  0.094000
# 1    1.5  0.135137
# 2    2.0  0.166398
# 3    2.5  0.192651
# 4    3.0  0.215732

# %% [markdown]
# ## Pokemon base stats

# %%
pokemon = stats_scraper.parse_entries(stats_scraper.load_raw(PROJECT_ROOT / "pokemon.json"))
pokemon.head()
# Out:
#    index  number  form_id                   name                       slug  \
# 0      0       1       87              Bulbasaur                1-bulbasaur
# 1      1       1      301  Bulbasaur (Fall 2019)      1-bulbasaur/fall-2019
# 2      2       2       90                Ivysaur                  2-ivysaur
# 3      3       3       93               Venusaur                 3-venusaur
# 4      4       3      436          Mega Venusaur  3-venusaur/mega-evolution
#
#              types   hp  attack  defense  is_variant
# 0  [Grass, Poison]  128     118      111       False
# 1  [Grass, Poison]  128     118      111       False
# 2  [Grass, Poison]  155     151      143       False
# 3  [Grass, Poison]  190     198      189       False
# 4  [Grass, Poison]  190     241      246        True
